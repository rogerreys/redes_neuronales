# %% [markdown]
# # La neurona | Perceptron
#
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b0/Perceptr%C3%B3n_5_unidades.svg/600px-Perceptr%C3%B3n_5_unidades.svg.png" width="500px">
# <img src="https://blog.josemarianoalvarez.com/wp-content/uploads/2018/06/ModeloPerceptron-1024x592.jpeg" width="500px">
#
#
#
#  Cada neurona tiene un peso, estos pesos van a cambiar en cada iteracion para que puedan resolver un problema
# b → va a cambiar para mover la curva
#  ![image.png](attachment:image.png)
#
# ## Perceptron AND
# Para el primer perceptron, los pesos no dan como resultado una salida AND
#
# <img src="src/img/and_incorrect.png" width="500px"/>
#
# <img src="src/img/and.png" width="500px"/>
#
# ## Perceptron Or
# <img src="src/img/or.png" width="500px"/>
#
# ## Plano cartesiano
# <img src="https://b2633864.smushcdn.com/2633864/wp-content/uploads/2021/04/bitwise_datasets-768x273.png?lossy=1&strip=1&webp=1" width="500px">
#
# ## Perceptron XOR
#
# <img src="src/img/xor_cart.png" width="500px">
#
# <img src="src/img/xor.png" width="500px">
