# %% [markdown]
# # Backpropagation
# ¿Como varia el coste ante un cambio del parametro w?
# $$\frac{dC}{dw}$$
#
# <img src="src/img/perceptron_back.png" width="500px">
#
# $$\frac{dC}{dw} \frac{dC}{dw}$$
#
# <img src="src/img/back_ult_capa.png" width="500px">
#
# ## Dericadas de la ultima capa
#
# <img src="src/img/valor_z_back.png" width="500px">
#
# <img src="src/img/calculo_error_back.png" width="500px">
#
# ## Chain rule, (regla de cadena)
#
# <img src="src/img/chain_rule_back.png" width="500px">
#
# <img src="src/img/funcion_coste_back.png" width="500px">
#
# <img src="src/img/funcion_activacion_back.png" width="500px">
#
# <img src="src/img/suma_ponderada_back.png" width="500px">
#
# <img src="src/img/derivacion_total_back.png" width="900px">
#
# La derivada del coste con la suma poderada, es la que nos va a indicar el error
# - Si la derivada es grande → En un pequeño cambio en el valor de la neurona, este se vera reflejado en el resultado final
# - Si la derivada es pequeña → Da igual como variemos el valor de la suma, este no afectara el valor de la red
#
# <img src="src/img/derivada_coste_z_back.png" width="500px">
#
# <img src="src/img/error_imputado_back.png" width="500px">
#
# Reemplazando la derivada, con el error imputado nos da:
#
# <img src="src/img/derivadas_error_inputado_back.png" width="500px">
#
# <img src="src/img/derivadas_error_inputado_desp_back.png" width="500px">
#
# Asi ya se encontro, el valor para las derivadas parciales que se esta buscando para la ultima capa
#
# <img src="src/img/tres_derivadas_back.png" width="500px">
#
#
# Para calcular el error en las otras capas anteriores, se debe usar las tres anteriores y un valor adicional
#
# <img src="src/img/derivada_L_1_back.png" width="700px">
#
# <img src="src/img/derivada_L_1_back_reemplazo.png" width="700px">
#
# Los pasos para realizar la derivada en la capa anterior es la siguiente
#
# <img src="src/img/derivada_L_1_pasos.png" width="500px">
#
#
# <!-- <img src="src/img/backpro.png">
#
# <img src="src/img/backpro_derivada.png"> -->
